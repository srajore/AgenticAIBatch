# %% [markdown]
# # 🕵️‍♂️ Project Nexus: Client 360 Assistant (AgentExecutor Version)
# **Module:** Agentic AI Day 2 (Tools & Mechanics)
# **Objective:** Solve the Project Nexus business case using the high-level `AgentExecutor` framework for rapid prototyping.
#
# ---
#
# ### 📋 Architecture
# Instead of writing the `while` loop manually, we will use LangChain's **`AgentExecutor`**.
# This class handles:
# 1.  Calling the LLM.
# 2.  Parsing the Tool Calls.
# 3.  Executing the Tools.
# 4.  Handling Errors.
# 5.  Managing History (`agent_scratchpad`).

# %%
# CELL 1: SETUP & IMPORTS
import os
import getpass
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool, StructuredTool
from pydantic import BaseModel, Field
from langchain_core.prompts import ChatPromptTemplate

# API Key Check
if not os.environ.get("OPENAI_API_KEY"):
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter OpenAI API Key: ")

# Initialize Brain
llm = ChatOpenAI(model="gpt-4o", temperature=0)
print("✅ Setup Complete")
# Out:
# ✅ Setup Complete

# %%
# CELL 2: MOCK DATABASE
CLIENT_DB = {
    "Acme Corp": {"industry": "Retail", "contact": "Alice Smith"},
    "Globex": {"industry": "Tech", "contact": "Bob Jones"},
    "Soylent Corp": {"industry": "Food", "contact": "Carol White"}
}

# %% [markdown]
# ### 🛠️ Step 1: Define Tools
# We use the same robust tool definitions as the manual version.

# %%
# CELL 3: TOOL DEFINITIONS

# --- TOOL A: RETRIEVAL ---
@tool
def get_client_details(client_name: str) -> str:
    """Retrieves industry and key contact for a client.
    Returns an error string if client is not found."""
    
    for key, value in CLIENT_DB.items():
        if key.lower() == client_name.lower():
            return f"Client: {key} | Industry: {value['industry']} | Contact: {value['contact']}"
            
    return f"Error: Client '{client_name}' not found in the database."

# --- TOOL B: SCHEDULER (With Pydantic) ---
class ScheduleInput(BaseModel):
    client_name: str = Field(description="Name of the client")
    date: str = Field(description="Date of the meeting (e.g., 'Oct 20th')")
    duration_minutes: int = Field(description="Duration in minutes (must be an integer)")

def schedule_meeting_func(client_name: str, date: str, duration_minutes: int) -> str:
    """Schedules a meeting in the calendar."""
    return f"SUCCESS: Meeting scheduled with {client_name} on {date} for {duration_minutes} minutes."

schedule_tool = StructuredTool.from_function(
    func=schedule_meeting_func,
    name="schedule_meeting",
    description="Schedule a meeting with a client.",
    args_schema=ScheduleInput
)

# List of tools
tools = [get_client_details, schedule_tool]
print("✅ Tools Ready")
# Out:
# ✅ Tools Ready

# %% [markdown]
# ### 🤖 Step 2: Create the AgentExecutor
# Here we construct the "Easy Button". Note that `AgentExecutor` requires a prompt with a placeholder for `{agent_scratchpad}`.

# %%
# CELL 4: AGENT CONSTRUCTION
from langchain.agents import create_agent

# 1. Define the Prompt - create_agent handles this internally
# 2. Create and execute the agent
nexus_agent = create_agent(llm, tools, debug=True)

print("✅ Agent Ready")
# Out:
# ✅ Agent Ready

# %% [markdown]
# ### 🧪 Step 3: Execution
# Let's test the agent against the requirements.

# %%
# SCENARIO 1: Composite Task (Lookup + Act)
query = "Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th."

print(f"🚀 EXECUTING: '{query}'")
response = nexus_agent.invoke({"messages": [("user", query)]})

print("-" * 50)
print(f"🏁 FINAL OUTPUT: {response['messages'][-1].content}")
# Out:
# 🚀 EXECUTING: 'Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.'
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es')]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es')]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 182, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6QyG91TF56HzI52yIXIL12OqJr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bfe32acf-18a1-471b-98ac-e8f0dd3f0819-0', tool_calls=[{'name': 'schedule_meeting', 'args': {'client_name': 'Acme Corp', 'date': 'Oct 20th', 'duration_minutes': 45}, 'id': 'call_vijlrXLxY7pkBvjfbuOxi9cK', 'type': 'tool_call'}], usage_metadata={'input_tokens': 182, 'output_tokens': 30, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 182, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6QyG91TF56HzI52yIXIL12OqJr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bfe32acf-18a1-471b-98ac-e8f0dd3f0819-0', tool_calls=[{'name': 'schedule_meeting', 'args': {'client_name': 'Acme Corp', 'date': 'Oct 20th', 'duration_minutes': 45}, 'id': 'call_vijlrXLxY7pkBvjfbuOxi9cK', 'type': 'tool_call'}], usage_metadata={'input_tokens': 182, 'output_tokens': 30, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='SUCCESS: Meeting scheduled with Acme Corp on Oct 20th for 45 minutes.', name='schedule_meeting', id='3414d459-ad8a-414e-a424-21a6ed5808e2', tool_call_id='call_vijlrXLxY7pkBvjfbuOxi9cK')]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 182, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6QyG91TF56HzI52yIXIL12OqJr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bfe32acf-18a1-471b-98ac-e8f0dd3f0819-0', tool_calls=[{'name': 'schedule_meeting', 'args': {'client_name': 'Acme Corp', 'date': 'Oct 20th', 'duration_minutes': 45}, 'id': 'call_vijlrXLxY7pkBvjfbuOxi9cK', 'type': 'tool_call'}], usage_metadata={'input_tokens': 182, 'output_tokens': 30, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='SUCCESS: Meeting scheduled with Acme Corp on Oct 20th for 45 minutes.', name='schedule_meeting', id='3414d459-ad8a-414e-a424-21a6ed5808e2', tool_call_id='call_vijlrXLxY7pkBvjfbuOxi9cK')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 182, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6QyG91TF56HzI52yIXIL12OqJr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bfe32acf-18a1-471b-98ac-e8f0dd3f0819-0', tool_calls=[{'name': 'schedule_meeting', 'args': {'client_name': 'Acme Corp', 'date': 'Oct 20th', 'duration_minutes': 45}, 'id': 'call_vijlrXLxY7pkBvjfbuOxi9cK', 'type': 'tool_call'}], usage_metadata={'input_tokens': 182, 'output_tokens': 30, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 182, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6QyG91TF56HzI52yIXIL12OqJr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bfe32acf-18a1-471b-98ac-e8f0dd3f0819-0', tool_calls=[{'name': 'schedule_meeting', 'args': {'client_name': 'Acme Corp', 'date': 'Oct 20th', 'duration_minutes': 45}, 'id': 'call_vijlrXLxY7pkBvjfbuOxi9cK', 'type': 'tool_call'}], usage_metadata={'input_tokens': 182, 'output_tokens': 30, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content='SUCCESS: Meeting scheduled with Acme Corp on Oct 20th for 45 minutes.', name='schedule_meeting', id='3414d459-ad8a-414e-a424-21a6ed5808e2', tool_call_id='call_vijlrXLxY7pkBvjfbuOxi9cK')]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 182, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6QyG91TF56HzI52yIXIL12OqJr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bfe32acf-18a1-471b-98ac-e8f0dd3f0819-0', tool_calls=[{'name': 'schedule_meeting', 'args': {'client_name': 'Acme Corp', 'date': 'Oct 20th', 'duration_minutes': 45}, 'id': 'call_vijlrXLxY7pkBvjfbuOxi9cK', 'type': 'tool_call'}], usage_metadata={'input_tokens': 182, 'output_tokens': 30, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='SUCCESS: Meeting scheduled with Acme Corp on Oct 20th for 45 minutes.', name='schedule_meeting', id='3414d459-ad8a-414e-a424-21a6ed5808e2', tool_call_id='call_vijlrXLxY7pkBvjfbuOxi9cK')]}
# [updates] {'model': {'messages': [AIMessage(content='I have successfully scheduled a 45-minute meeting with Acme Corp on October 20th. The key contact for Acme Corp is Alice Smith.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 239, 'total_tokens': 270, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6RhbZNdZ6VZHgadmKkX1zvfyz0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ecd5a0bf-ab85-4120-b290-51972175c2ce-0', usage_metadata={'input_tokens': 239, 'output_tokens': 31, 'total_tokens': 270, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 182, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6QyG91TF56HzI52yIXIL12OqJr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bfe32acf-18a1-471b-98ac-e8f0dd3f0819-0', tool_calls=[{'name': 'schedule_meeting', 'args': {'client_name': 'Acme Corp', 'date': 'Oct 20th', 'duration_minutes': 45}, 'id': 'call_vijlrXLxY7pkBvjfbuOxi9cK', 'type': 'tool_call'}], usage_metadata={'input_tokens': 182, 'output_tokens': 30, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='SUCCESS: Meeting scheduled with Acme Corp on Oct 20th for 45 minutes.', name='schedule_meeting', id='3414d459-ad8a-414e-a424-21a6ed5808e2', tool_call_id='call_vijlrXLxY7pkBvjfbuOxi9cK'), AIMessage(content='I have successfully scheduled a 45-minute meeting with Acme Corp on October 20th. The key contact for Acme Corp is Alice Smith.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 239, 'total_tokens': 270, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6RhbZNdZ6VZHgadmKkX1zvfyz0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ecd5a0bf-ab85-4120-b290-51972175c2ce-0', usage_metadata={'input_tokens': 239, 'output_tokens': 31, 'total_tokens': 270, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# --------------------------------------------------
# 🏁 FINAL OUTPUT: I have successfully scheduled a 45-minute meeting with Acme Corp on October 20th. The key contact for Acme Corp is Alice Smith.
# [updates] {'model': {'messages': [AIMessage(content='I have successfully scheduled a 45-minute meeting with Acme Corp on October 20th. The key contact for Acme Corp is Alice Smith.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 239, 'total_tokens': 270, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6RhbZNdZ6VZHgadmKkX1zvfyz0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ecd5a0bf-ab85-4120-b290-51972175c2ce-0', usage_metadata={'input_tokens': 239, 'output_tokens': 31, 'total_tokens': 270, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Find the contact for Acme Corp and book a 45 min meeting with them on Oct 20th.', additional_kwargs={}, response_metadata={}, id='05b4d663-5b93-4ffe-a3cc-62b43ffb6342'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 141, 'total_tokens': 159, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6O6CEHSxTcWStnByOC1ayE7n0z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--f9d80f13-a678-4619-9a4c-bd1f926e5036-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Acme Corp'}, 'id': 'call_tcbvGH0T0J5TDMUH8b4zt4Es', 'type': 'tool_call'}], usage_metadata={'input_tokens': 141, 'output_tokens': 18, 'total_tokens': 159, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='Client: Acme Corp | Industry: Retail | Contact: Alice Smith', name='get_client_details', id='f5b48571-76a1-4457-b15b-5bf2cbfb3eec', tool_call_id='call_tcbvGH0T0J5TDMUH8b4zt4Es'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 30, 'prompt_tokens': 182, 'total_tokens': 212, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6QyG91TF56HzI52yIXIL12OqJr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--bfe32acf-18a1-471b-98ac-e8f0dd3f0819-0', tool_calls=[{'name': 'schedule_meeting', 'args': {'client_name': 'Acme Corp', 'date': 'Oct 20th', 'duration_minutes': 45}, 'id': 'call_vijlrXLxY7pkBvjfbuOxi9cK', 'type': 'tool_call'}], usage_metadata={'input_tokens': 182, 'output_tokens': 30, 'total_tokens': 212, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='SUCCESS: Meeting scheduled with Acme Corp on Oct 20th for 45 minutes.', name='schedule_meeting', id='3414d459-ad8a-414e-a424-21a6ed5808e2', tool_call_id='call_vijlrXLxY7pkBvjfbuOxi9cK'), AIMessage(content='I have successfully scheduled a 45-minute meeting with Acme Corp on October 20th. The key contact for Acme Corp is Alice Smith.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 239, 'total_tokens': 270, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6RhbZNdZ6VZHgadmKkX1zvfyz0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ecd5a0bf-ab85-4120-b290-51972175c2ce-0', usage_metadata={'input_tokens': 239, 'output_tokens': 31, 'total_tokens': 270, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# --------------------------------------------------
# 🏁 FINAL OUTPUT: I have successfully scheduled a 45-minute meeting with Acme Corp on October 20th. The key contact for Acme Corp is Alice Smith.

# %%
# SCENARIO 2: Error Handling (Missing Client)
query = "Book a meeting with Nvidia."

response = nexus_agent.invoke({"messages": [("user", query)]})
# Out:
# [values] {'messages': [HumanMessage(content='Book a meeting with Nvidia.', additional_kwargs={}, response_metadata={}, id='d244f8c0-7cda-4530-9934-7ec162f8763e')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 125, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6TintJldHOP5vgw9zlJuNB5FMa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--a8a30c0f-8e93-4ca2-b406-5c22d0e03bd4-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Nvidia'}, 'id': 'call_w39V64456iyz2VlKQPIksxLQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 125, 'output_tokens': 17, 'total_tokens': 142, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Book a meeting with Nvidia.', additional_kwargs={}, response_metadata={}, id='d244f8c0-7cda-4530-9934-7ec162f8763e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 125, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6TintJldHOP5vgw9zlJuNB5FMa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--a8a30c0f-8e93-4ca2-b406-5c22d0e03bd4-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Nvidia'}, 'id': 'call_w39V64456iyz2VlKQPIksxLQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 125, 'output_tokens': 17, 'total_tokens': 142, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content="Error: Client 'Nvidia' not found in the database.", name='get_client_details', id='e7103574-34d1-46d1-8101-59390902cfda', tool_call_id='call_w39V64456iyz2VlKQPIksxLQ')]}}
# [values] {'messages': [HumanMessage(content='Book a meeting with Nvidia.', additional_kwargs={}, response_metadata={}, id='d244f8c0-7cda-4530-9934-7ec162f8763e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 125, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6TintJldHOP5vgw9zlJuNB5FMa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--a8a30c0f-8e93-4ca2-b406-5c22d0e03bd4-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Nvidia'}, 'id': 'call_w39V64456iyz2VlKQPIksxLQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 125, 'output_tokens': 17, 'total_tokens': 142, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="Error: Client 'Nvidia' not found in the database.", name='get_client_details', id='e7103574-34d1-46d1-8101-59390902cfda', tool_call_id='call_w39V64456iyz2VlKQPIksxLQ')]}
# [updates] {'model': {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 125, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6TintJldHOP5vgw9zlJuNB5FMa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--a8a30c0f-8e93-4ca2-b406-5c22d0e03bd4-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Nvidia'}, 'id': 'call_w39V64456iyz2VlKQPIksxLQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 125, 'output_tokens': 17, 'total_tokens': 142, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Book a meeting with Nvidia.', additional_kwargs={}, response_metadata={}, id='d244f8c0-7cda-4530-9934-7ec162f8763e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 125, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6TintJldHOP5vgw9zlJuNB5FMa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--a8a30c0f-8e93-4ca2-b406-5c22d0e03bd4-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Nvidia'}, 'id': 'call_w39V64456iyz2VlKQPIksxLQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 125, 'output_tokens': 17, 'total_tokens': 142, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'tools': {'messages': [ToolMessage(content="Error: Client 'Nvidia' not found in the database.", name='get_client_details', id='e7103574-34d1-46d1-8101-59390902cfda', tool_call_id='call_w39V64456iyz2VlKQPIksxLQ')]}}
# [values] {'messages': [HumanMessage(content='Book a meeting with Nvidia.', additional_kwargs={}, response_metadata={}, id='d244f8c0-7cda-4530-9934-7ec162f8763e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 125, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6TintJldHOP5vgw9zlJuNB5FMa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--a8a30c0f-8e93-4ca2-b406-5c22d0e03bd4-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Nvidia'}, 'id': 'call_w39V64456iyz2VlKQPIksxLQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 125, 'output_tokens': 17, 'total_tokens': 142, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="Error: Client 'Nvidia' not found in the database.", name='get_client_details', id='e7103574-34d1-46d1-8101-59390902cfda', tool_call_id='call_w39V64456iyz2VlKQPIksxLQ')]}
# [updates] {'model': {'messages': [AIMessage(content="It seems that Nvidia is not in our database. Could you please provide more details or verify the client's name?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 164, 'total_tokens': 187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6UrKBIY7qCKycPjp2uGx6DirII', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--f24213f4-92c8-4c6c-8451-13e3dc80c261-0', usage_metadata={'input_tokens': 164, 'output_tokens': 23, 'total_tokens': 187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Book a meeting with Nvidia.', additional_kwargs={}, response_metadata={}, id='d244f8c0-7cda-4530-9934-7ec162f8763e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 125, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6TintJldHOP5vgw9zlJuNB5FMa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--a8a30c0f-8e93-4ca2-b406-5c22d0e03bd4-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Nvidia'}, 'id': 'call_w39V64456iyz2VlKQPIksxLQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 125, 'output_tokens': 17, 'total_tokens': 142, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="Error: Client 'Nvidia' not found in the database.", name='get_client_details', id='e7103574-34d1-46d1-8101-59390902cfda', tool_call_id='call_w39V64456iyz2VlKQPIksxLQ'), AIMessage(content="It seems that Nvidia is not in our database. Could you please provide more details or verify the client's name?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 164, 'total_tokens': 187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6UrKBIY7qCKycPjp2uGx6DirII', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--f24213f4-92c8-4c6c-8451-13e3dc80c261-0', usage_metadata={'input_tokens': 164, 'output_tokens': 23, 'total_tokens': 187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# [updates] {'model': {'messages': [AIMessage(content="It seems that Nvidia is not in our database. Could you please provide more details or verify the client's name?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 164, 'total_tokens': 187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6UrKBIY7qCKycPjp2uGx6DirII', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--f24213f4-92c8-4c6c-8451-13e3dc80c261-0', usage_metadata={'input_tokens': 164, 'output_tokens': 23, 'total_tokens': 187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
# [values] {'messages': [HumanMessage(content='Book a meeting with Nvidia.', additional_kwargs={}, response_metadata={}, id='d244f8c0-7cda-4530-9934-7ec162f8763e'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 125, 'total_tokens': 142, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6TintJldHOP5vgw9zlJuNB5FMa', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--a8a30c0f-8e93-4ca2-b406-5c22d0e03bd4-0', tool_calls=[{'name': 'get_client_details', 'args': {'client_name': 'Nvidia'}, 'id': 'call_w39V64456iyz2VlKQPIksxLQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 125, 'output_tokens': 17, 'total_tokens': 142, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="Error: Client 'Nvidia' not found in the database.", name='get_client_details', id='e7103574-34d1-46d1-8101-59390902cfda', tool_call_id='call_w39V64456iyz2VlKQPIksxLQ'), AIMessage(content="It seems that Nvidia is not in our database. Could you please provide more details or verify the client's name?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 164, 'total_tokens': 187, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-CgW6UrKBIY7qCKycPjp2uGx6DirII', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--f24213f4-92c8-4c6c-8451-13e3dc80c261-0', usage_metadata={'input_tokens': 164, 'output_tokens': 23, 'total_tokens': 187, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
